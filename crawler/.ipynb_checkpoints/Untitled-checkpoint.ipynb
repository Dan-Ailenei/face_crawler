# %%
import requests
from bs4 import BeautifulSoup
from io import BytesIO
from PIL import Image

# %%
resp = requests.get('https://www.facebook.com/dan.ailenei.9')

# %%
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
scripts = soup.find_all('script')

# %%
for script in scripts:
    print('\n' * 4)
    print(script)

# %%
# filtru de clasa nu e fezabil
elems = soup.find_all('img', {'class': '_11kf img'})

# %%
elems
# Out:
# [<img alt="Fotografia de profil a lui Dan Ailenei, Este posibil ca imaginea să conţină: 1 persoană, interior" class="_11kf img" src="https://scontent.fclj2-1.fna.fbcdn.net/v/t1.0-1/p160x160/25353612_1517843281656424_5882133087425243915_n.jpg?_nc_cat=107&amp;_nc_ht=scontent.fclj2-1.fna&amp;oh=bcccc1cce664326140d440093905111e&amp;oe=5D4BBB24"/>]

# %%
# odata a fost prima imagine iar altadata a 2-a
img_url = elems[0].get('src')

# %%
image_request = requests.get(img_url)

# %%
image_bytes = image_request.content

# %%
img = Image.open(BytesIO(image_bytes))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x160 at 0x17AD766CE80>

# %%
resp = requests.get('https://www.facebook.com/mouna.joudar.massaoudi')
resp.status_code
# Out:
# 404

# %%
resp = requests.get('https://www.facebook.com/photo.php?fbid=10213913833541606&set=a.1364986486345&type=3&theater')
resp.status_code
# Out:
# 200

# %% [markdown]
# Pagina DESPRE, pentru a lua date publice

# %%
resp = requests.get('https://www.facebook.com/dan.ailenei.9/about?lst=100002923005583%3A100002923005583%3A1553619791&section=contact-info')
resp.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
soup.find_all("span")
# Out:
# [<span class="mrm _3bcv _50f3">Sari la</span>,
#  <span class="_55pe">Secţiuni ale acestei pagini</span>,
#  <span class="_4o_3 _3-99"><i class="img sp_CDBF8O5xgeq sx_2cde5d"></i></span>,
#  <span class="_55pe">Ajutor pentru accesibilitate</span>,
#  <span class="_4o_3 _3-99"><i class="img sp_CDBF8O5xgeq sx_591efb"></i></span>,
#  <span class="_3bcz">alt</span>,
#  <span class="_3bcz">/</span>,
#  <span class="muffin_tracking_pixel_start"></span>,
#  <span class="muffin_tracking_pixel_end"></span>,
#  <span class="coverWrap coverImage" data-cropped="1" id="fbCoverImageContainer"><img alt="Fotografie de copertă, Este posibil ca imaginea să conţină: 1 persoană" class="coverPhotoImg photo img" data-fbid="560574384049990" src="https://scontent.fclj2-1.fna.fbcdn.net/v/t31.0-8/c0.68.851.315a/p851x315/1782472_560574384049990_728731316_o.jpg?_nc_cat=101&amp;_nc_ht=scontent.fclj2-1.fna&amp;oh=6ae8bff72a3e363efa42c94a4b0745ae&amp;oe=5D0B7F27" style="top:0px;width:100%"/><div class="coverBorder"></div><img alt="" class="coverChangeThrobber img" height="16" src="https://static.xx.fbcdn.net/rsrc.php/v3/yk/r/LOOn0JtHNzb.gif" width="16"/></span>,
#  <span class="_2t_q" data-testid="profile_name_in_profile_page" id="fb-timeline-cover-name"><a class="_2nlw _2nlv" href="https://www.facebook.com/dan.ailenei.9">Dan Ailenei</a></span>,
#  <span class="_2nly"></span>,
#  <span class="_4u6v">sau</span>,
>, <a href="https://www.facebook.com/K.airsoft/">k-airsoft.ro</a>, <a href="https://www.facebook.com/Aeroclubul.Romaniei/">Aeroclubul României</a>, <a href="https://www.facebook.com/clujpm/">Cluj Perl Mongers</a>, <a href="https://www.facebook.com/evozon/">evozon</a>, <a href="https://www.facebook.com/DancesJoy/">Stumbler Videos</a>, <a href="https://www.facebook.com/transpotpersoanebrasov/">Transport persoane brasov</a>, <a href="https://www.facebook.com/tanasegeorgeofficial/">Tănase George</a>, <a href="https://www.facebook.com/danaturmentata/">Dana Bacinschi</a>, <a href="https://www.facebook.com/ChefGianny/">Chef Gianny</a>, <a href="https://www.facebook.com/BerariaCiucasBrasov/">Beraria Ciucas Brasov</a>, <a href="https://www.facebook.com/targuldecariere/">Târgul de Cariere</a>, <a href="https://www.facebook.com/cariereinit/">cariereinit.ro</a>, <a href="https://www.facebook.com/IrishMusicPubCluj/">Irish MusicPub</a>, <a href="https://www.facebook.com/omnipass.ro/">OmniPass</a>, <a href="https://www.facebook.com/destresiune/">Destresiune</a>, <a href="https://www.facebook.com/mariusMAGITOTdragus/">MAGITOT</a>, <a href="https://www.facebook.com/Vlad-Ionut-Coste-2073311989561112/">Vlad Ionut Coste</a>, <a href="https://www.facebook.com/alexmocanustandup/">Alex Mocanu</a>, <a href="https://www.facebook.com/Immoglobalrealestate/">ImmoGlobal Real Estate</a>, <a href="https://www.facebook.com/CatalinScarlatescu/">Chef Catalin Scarlatescu</a>, <a href="https://www.facebook.com/romaniansarecoming/">The Romanians Are Coming</a>, <a href="https://www.facebook.com/intreshowuri/">Intre Showuri Podcast</a>, <a href="https://www.facebook.com/chefflorindumitrescu/">Chef Florin Dumitrescu</a>, <a href="https://www.facebook.com/Nae.Nicolae.Comediant/">Nae Nicolae</a>, <a href="https://www.facebook.com/brackeys/">Brackeys</a>, <a href="https://www.facebook.com/Despre-Univers-1577359872513523/">Despre Univers</a>, <a href="https://www.facebook.com/provocareav/">Provocarea #V</a>, <a href="https://www.facebook.com/fmi.ub/">Facultatea de Matematică și Informatică, Universitatea din București</a>, <a href="https://www.facebook.com/annevlog/">Vlog-ul de Marţi</a>, <a href="https://www.facebook.com/buzzfeedtasty/">Tasty</a>, <a href="https://www.facebook.com/pages/Nutella/113787735297989">Nutella</a>, <a href="https://www.facebook.com/Nutella/">Nutella</a>, <a href="https://www.facebook.com/officialjacksepticeye/">Jacksepticeye</a>, <a href="https://www.facebook.com/HourofCodeRo/">Hour of Code - Romania</a>, <a href="https://www.fac ...
#  <span aria-level="5" class="_h72 lfloat _ohe _50f7" role="heading">Informaţii de contact</span>,
#  <span class="_50f8 _2iem">Nu există informaţii de contact de afişat</span>,
#  <span><img height="0" src="https://facebook.com/security/hsts-pixel.gif?c=3.2.5" style="display:none" width="0"/></span>]

# %% [markdown]
# # Intrebarea cea mai buna e ... cand crap?

# %%
while resp.status_code == 200:
    resp = requests.get('https://www.facebook.com/photo.php?fbid=10213913833541606&set=a.1364986486345&type=3&theater')

# %% [markdown]
# Nu crapa
